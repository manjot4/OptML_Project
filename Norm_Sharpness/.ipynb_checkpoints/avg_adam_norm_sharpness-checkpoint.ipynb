# %%
""" This notebook contains code for computing norms and sharpness values for Adam
Results are averaged over 3 random seeds to minimize the variation"""

# %tensorflow_version 2.x
import tensorflow as tf
device = tf.test.gpu_device_name()
if device != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device))

from google.colab import drive
drive.mount('/content/drive')


# %cd /content/drive/My Drive/Colab Notebooks

# %%
# Importing Libraries
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
import argparse, copy

from model import *
from utils import *
from measures import *

# %%
"""We do a grid search over the learning rates. 
We chose learning rate with the lowest validation loss.
Results are averaged over 3 random seeds to minimize the variation."""

validation_losses = []
seeds = [12345, 1234, 123]
for seed in seeds:
    print ("seed:::", seed)
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Model Hyperparamters
    batch_size = 64
    epochs = 14
    lrs = [1e-1,3e-2, 3e-3, 3e-4, 2e-5]  
    gamma = 0.7
    momentum = 0.0

    use_cuda = torch.cuda.is_available()
    train_loader, val_loader, test_loader, train_size, val_size = dataloaders(batch_size, use_cuda, seed)
    print (train_size, val_size, len(test_loader.dataset))

    model = Net().to(device)
    
    # Grid Search over different learning rates - over validation dataset
    val_losses = []
    for lr in lrs:
        print ("lr:", lr)
        model_copy = copy.deepcopy(model)
        optimizer = optim.Adam(model_copy.parameters(), lr=lr)
        scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

        for epoch in range(1, epochs + 1):
            train_loss = train(model_copy, device, train_loader, optimizer, epoch, batch_size)
            val_loss = test_2(model_copy, device, val_loader, batch_size, val_size)
            # test_loss = test(model_copy, device, test_loader, batch_size)  # one can see on test_loss as well.....
            scheduler.step()
        val_losses.append(val_loss)
    validation_losses.append(val_losses)
# Out:
# seed::: 12345
# 54000 6000 10000
# lr: 0.1
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
#
# Test set: Average loss: 2.3022, Accuracy: 636/6000 (11%)
#
# lr: 0.03
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 635/6000 (11%)
#
# lr: 0.003
#
# Test set: Average loss: 1.3318, Accuracy: 3337/6000 (56%)
#
#
# Test set: Average loss: 1.0465, Accuracy: 4030/6000 (67%)
#
#
# Test set: Average loss: 1.0156, Accuracy: 4075/6000 (68%)
#
#
# Test set: Average loss: 0.9988, Accuracy: 4108/6000 (68%)
#
#
# Test set: Average loss: 0.9945, Accuracy: 4105/6000 (68%)
#
#
# Test set: Average loss: 0.9891, Accuracy: 4129/6000 (69%)
#
#
# Test set: Average loss: 0.9894, Accuracy: 4130/6000 (69%)
#
#
# Test set: Average loss: 0.9949, Accuracy: 4127/6000 (69%)
#
#
# Test set: Average loss: 0.9967, Accuracy: 4132/6000 (69%)
#
#
# Test set: Average loss: 0.9942, Accuracy: 4134/6000 (69%)
#
#
# Test set: Average loss: 0.9957, Accuracy: 4131/6000 (69%)
#
#
# Test set: Average loss: 0.9956, Accuracy: 4135/6000 (69%)
#
#
# Test set: Average loss: 0.9968, Accuracy: 4135/6000 (69%)
#
#
# Test set: Average loss: 0.9991, Accuracy: 4134/6000 (69%)
#
# lr: 0.0003
#
# Test set: Average loss: 1.0222, Accuracy: 3487/6000 (58%)
#
#
# Test set: Average loss: 0.9815, Accuracy: 3544/6000 (59%)
#
#
# Test set: Average loss: 0.9762, Accuracy: 3550/6000 (59%)
#
#
# Test set: Average loss: 0.9718, Accuracy: 3552/6000 (59%)
#
#
# Test set: Average loss: 0.9672, Accuracy: 3554/6000 (59%)
#
#
# Test set: Average loss: 0.9713, Accuracy: 3558/6000 (59%)
#
#
# Test set: Average loss: 0.9727, Accuracy: 3556/6000 (59%)
#
#
# Test set: Average loss: 0.9703, Accuracy: 3560/6000 (59%)
#
#
# Test set: Average loss: 0.9712, Accuracy: 3561/6000 (59%)
#
#
# Test set: Average loss: 0.9699, Accuracy: 3564/6000 (59%)
#
#
# Test set: Average loss: 0.9717, Accuracy: 3560/6000 (59%)
#
#
# Test set: Average loss: 0.9721, Accuracy: 3565/6000 (59%)
#
#
# Test set: Average loss: 0.9732, Accuracy: 3561/6000 (59%)
#
#
# Test set: Average loss: 0.9738, Accuracy: 3564/6000 (59%)
#
# lr: 2e-05
#
# Test set: Average loss: 0.5437, Accuracy: 4883/6000 (81%)
#
#
# Test set: Average loss: 0.4924, Accuracy: 4964/6000 (83%)
#
#
# Test set: Average loss: 0.4684, Accuracy: 5006/6000 (83%)
#
#
# Test set: Average loss: 0.4542, Accuracy: 5035/6000 (84%)
#
#
# Test set: Average loss: 0.4458, Accuracy: 5052/6000 (84%)
#
#
# Test set: Average loss: 0.4404, Accuracy: 5059/6000 (84%)
#
#
# Test set: Average loss: 0.4368, Accuracy: 5072/6000 (85%)
#
#
# Test set: Average loss: 0.4334, Accuracy: 5070/6000 (84%)
#
#
# Test set: Average loss: 0.4315, Accuracy: 5077/6000 (85%)
#
#
# Test set: Average loss: 0.4307, Accuracy: 5075/6000 (85%)
#
#
# Test set: Average loss: 0.4300, Accuracy: 5078/6000 (85%)
#
#
# Test set: Average loss: 0.4293, Accuracy: 5079/6000 (85%)
#
#
# Test set: Average loss: 0.4289, Accuracy: 5078/6000 (85%)
#
#
# Test set: Average loss: 0.4291, Accuracy: 5078/6000 (85%)
#
# seed::: 1234
# 54000 6000 10000
# lr: 0.1
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 605/6000 (10%)
#
# lr: 0.03
#
# Test set: Average loss: 2.3031, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
#
# Test set: Average loss: 2.3030, Accuracy: 604/6000 (10%)
#
# lr: 0.003
#
# Test set: Average loss: 1.6905, Accuracy: 2301/6000 (38%)
#
#
# Test set: Average loss: 1.6278, Accuracy: 2406/6000 (40%)
#
#
# Test set: Average loss: 1.6172, Accuracy: 2432/6000 (41%)
#
#
# Test set: Average loss: 1.4228, Accuracy: 2984/6000 (50%)
#
#
# Test set: Average loss: 1.4116, Accuracy: 2988/6000 (50%)
#
#
# Test set: Average loss: 1.4033, Accuracy: 3000/6000 (50%)
#
#
# Test set: Average loss: 1.1893, Accuracy: 3589/6000 (60%)
#
#
# Test set: Average loss: 1.1838, Accuracy: 3603/6000 (60%)
#
#
# Test set: Average loss: 1.1795, Accuracy: 3602/6000 (60%)
#
#
# Test set: Average loss: 1.1814, Accuracy: 3607/6000 (60%)
#
#
# Test set: Average loss: 1.1794, Accuracy: 3610/6000 (60%)
#
#
# Test set: Average loss: 1.1797, Accuracy: 3609/6000 (60%)
#
#
# Test set: Average loss: 1.1790, Accuracy: 3609/6000 (60%)
#
#
# Test set: Average loss: 1.1797, Accuracy: 3610/6000 (60%)
#
# lr: 0.0003
#
# Test set: Average loss: 0.3388, Accuracy: 5228/6000 (87%)
#
#
# Test set: Average loss: 0.3184, Accuracy: 5259/6000 (88%)
#
#
# Test set: Average loss: 0.2928, Accuracy: 5305/6000 (88%)
#
#
# Test set: Average loss: 0.2895, Accuracy: 5305/6000 (88%)
#
#
# Test set: Average loss: 0.2824, Accuracy: 5319/6000 (89%)
#
#
# Test set: Average loss: 0.2804, Accuracy: 5315/6000 (89%)
#
#
# Test set: Average loss: 0.2835, Accuracy: 5318/6000 (89%)
#
#
# Test set: Average loss: 0.2830, Accuracy: 5318/6000 (89%)
#
#
# Test set: Average loss: 0.2817, Accuracy: 5323/6000 (89%)
#
#
# Test set: Average loss: 0.2827, Accuracy: 5322/6000 (89%)
#
#
# Test set: Average loss: 0.2818, Accuracy: 5320/6000 (89%)
#
#
# Test set: Average loss: 0.2835, Accuracy: 5323/6000 (89%)
#
#
# Test set: Average loss: 0.2825, Accuracy: 5320/6000 (89%)
#
#
# Test set: Average loss: 0.2830, Accuracy: 5321/6000 (89%)
#
# lr: 2e-05
#
# Test set: Average loss: 0.3214, Accuracy: 5428/6000 (90%)
#
#
# Test set: Average loss: 0.2623, Accuracy: 5537/6000 (92%)
#
#
# Test set: Average loss: 0.2378, Accuracy: 5577/6000 (93%)
#
#
# Test set: Average loss: 0.2236, Accuracy: 5597/6000 (93%)
#
#
# Test set: Average loss: 0.2120, Accuracy: 5628/6000 (94%)
#
#
# Test set: Average loss: 0.2061, Accuracy: 5634/6000 (94%)
#
#
# Test set: Average loss: 0.2024, Accuracy: 5641/6000 (94%)
#
#
# Test set: Average loss: 0.1987, Accuracy: 5642/6000 (94%)
#
#
# Test set: Average loss: 0.1973, Accuracy: 5645/6000 (94%)
#
#
# Test set: Average loss: 0.1958, Accuracy: 5643/6000 (94%)
#
#
# Test set: Average loss: 0.1948, Accuracy: 5644/6000 (94%)
#
#
# Test set: Average loss: 0.1941, Accuracy: 5647/6000 (94%)
#
#
# Test set: Average loss: 0.1940, Accuracy: 5648/6000 (94%)
#
#
# Test set: Average loss: 0.1938, Accuracy: 5646/6000 (94%)
#
# seed::: 123
# 54000 6000 10000
# lr: 0.1
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
# lr: 0.03
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
#
# Test set: Average loss: 2.3026, Accuracy: 658/6000 (11%)
#
# lr: 0.003
#
# Test set: Average loss: 1.8960, Accuracy: 1766/6000 (29%)
#
#
# Test set: Average loss: 1.8849, Accuracy: 1784/6000 (30%)
#
#
# Test set: Average loss: 1.6801, Accuracy: 2345/6000 (39%)
#
#
# Test set: Average loss: 1.6684, Accuracy: 2355/6000 (39%)
#
#
# Test set: Average loss: 1.6671, Accuracy: 2358/6000 (39%)
#
#
# Test set: Average loss: 1.6650, Accuracy: 2362/6000 (39%)
#
#
# Test set: Average loss: 1.6702, Accuracy: 2363/6000 (39%)
#
#
# Test set: Average loss: 1.6673, Accuracy: 2368/6000 (39%)
#
#
# Test set: Average loss: 1.6683, Accuracy: 2366/6000 (39%)
#
#
# Test set: Average loss: 1.6726, Accuracy: 2368/6000 (39%)
#
#
# Test set: Average loss: 1.6723, Accuracy: 2367/6000 (39%)
#
#
# Test set: Average loss: 1.6731, Accuracy: 2368/6000 (39%)
#
#
# Test set: Average loss: 1.6732, Accuracy: 2368/6000 (39%)
#
#
# Test set: Average loss: 1.6746, Accuracy: 2368/6000 (39%)
#
# lr: 0.0003
#
# Test set: Average loss: 0.3162, Accuracy: 5294/6000 (88%)
#
#
# Test set: Average loss: 0.2802, Accuracy: 5341/6000 (89%)
#
#
# Test set: Average loss: 0.2784, Accuracy: 5353/6000 (89%)
#
#
# Test set: Average loss: 0.2729, Accuracy: 5357/6000 (89%)
#
#
# Test set: Average loss: 0.2715, Accuracy: 5360/6000 (89%)
#
#
# Test set: Average loss: 0.2617, Accuracy: 5369/6000 (89%)
#
#
# Test set: Average loss: 0.2635, Accuracy: 5374/6000 (90%)
#
#
# Test set: Average loss: 0.2620, Accuracy: 5372/6000 (90%)
#
#
# Test set: Average loss: 0.2619, Accuracy: 5375/6000 (90%)
#
#
# Test set: Average loss: 0.2622, Accuracy: 5373/6000 (90%)
#
#
# Test set: Average loss: 0.2630, Accuracy: 5370/6000 (90%)
#
#
# Test set: Average loss: 0.2630, Accuracy: 5374/6000 (90%)
#
#
# Test set: Average loss: 0.2636, Accuracy: 5372/6000 (90%)
#
#
# Test set: Average loss: 0.2634, Accuracy: 5370/6000 (90%)
#
# lr: 2e-05
#
# Test set: Average loss: 0.3062, Accuracy: 5462/6000 (91%)
#
#
# Test set: Average loss: 0.2522, Accuracy: 5553/6000 (93%)
#
#
# Test set: Average loss: 0.2257, Accuracy: 5599/6000 (93%)
#
#
# Test set: Average loss: 0.2096, Accuracy: 5627/6000 (94%)
#
#
# Test set: Average loss: 0.2002, Accuracy: 5641/6000 (94%)
#
#
# Test set: Average loss: 0.1946, Accuracy: 5649/6000 (94%)
#
#
# Test set: Average loss: 0.1911, Accuracy: 5666/6000 (94%)
#
#
# Test set: Average loss: 0.1886, Accuracy: 5665/6000 (94%)
#
#
# Test set: Average loss: 0.1866, Accuracy: 5668/6000 (94%)
#
#
# Test set: Average loss: 0.1849, Accuracy: 5667/6000 (94%)
#
#
# Test set: Average loss: 0.1842, Accuracy: 5660/6000 (94%)
#
#
# Test set: Average loss: 0.1836, Accuracy: 5669/6000 (94%)
#
#
# Test set: Average loss: 0.1832, Accuracy: 5666/6000 (94%)
#
#
# Test set: Average loss: 0.1828, Accuracy: 5668/6000 (94%)

# %%
print (validation_losses)

#averaging validation losses over different seeds
validation_losses = np.mean(np.array(validation_losses), 0)
print (validation_losses)
# Out:
# [[2.30220213595857, 2.3025848789417998, 0.999107374789867, 0.9738004359793155, 0.42913399002653485], [2.3025848789417998, 2.302984815962771, 1.1797024759840458, 0.2829826831659104, 0.19380935352850467], [2.3025848789417998, 2.3025848789417998, 1.6745996995175139, 0.263384809083444, 0.18284079820868818]]
# [2.3024573  2.30271819 1.28446985 0.50672264 0.26859471]

# %%
# Learning Rates - ['1e-1', '3e-2', '3e-3', '3e-4', '2e-5']   plotted on log scale
lr_rates = np.log(np.array(lrs))
fig = plt.figure()
plt.plot(lr_rates, validation_losses, color='blue', marker='o') 
plt.xlabel('Learning Rates')
plt.ylabel('Validation Loss')
plt.title("Validation performance over different learning rates")
plt.grid(True, linestyle='-.')
fig.show()   
"""best lr = 2e-5 in case of Adam"""

"""please ignore the below line"""
# Out:
# 'best lr = 3e-6 in case of RMSprop'

# %%
# Results averaged over 3 different random seeds
avg_train_losses, avg_test_losses, avg_difference_test_train = [], [], []
avg_weight_norms_list, avg_sharpness_list, avg_std_list, avg_mean_list = [], [], [], []

seeds = [12345, 1234, 123]
for seed in seeds:
    print ("seed:::", seed)
    torch.manual_seed(seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Model Hyperparamters
    batch_size = 64
    epochs = 14
    lr  = 2e-5   # lowest validation loss
    gamma = 0.7
    momentum = 0.0

    use_cuda = torch.cuda.is_available()
    train_loader, val_loader, test_loader, train_size, val_size = dataloaders(batch_size, use_cuda, seed)
    print (train_size, val_size, len(test_loader.dataset))

    model = Net().to(device)

    train_losses, test_losses = [], []
    sigmas = [0.001,0.003,0.006,0.009,0.03,0.06,0.09]    
    delta = 1e-2
    mean = 0.0
    weight_norms_list = []
    sharpness_list = []

    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

    for epoch in range(1, epochs + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch, batch_size)
        train_losses.append(train_loss)
        test_loss = test(model, device, test_loader, batch_size)
        test_losses.append(test_loss)
        scheduler.step()
    
    avg_train_losses.append(train_losses) 
    avg_test_losses.append(test_losses)

    # print train and test losses and their difference
    difference_test_train = np.array(test_losses)  - np.array(train_losses)
    avg_difference_test_train.append(difference_test_train)

    print ("running for sigmas")
    """run for each sigma"""
    std_list = []
    mean_list = []

    for sigma in sigmas:
        weight_l2_norm = cal_l2_norm(model)
        weight_bound = compute_bound(model, train_size, sigma, weight_l2_norm, delta)  
        weight_norms_list.append(weight_bound)

        #to calculate sharpness, perturb the same model 20 times, then get expected value
        num_times = 20
        p_train_losses = []
        for iterate in range(num_times):
            p_model = copy.deepcopy(model)
            p_model = weight_pertubation(p_model, mean, sigma, device)
            p_train_loss = test_2(p_model, device, train_loader, batch_size, train_size)
            p_train_losses.append(p_train_loss)
        exp_p_error = sum(p_train_losses) / len(p_train_losses)
        std_list.append(np.std(np.array(p_train_losses)))
        mean_list.append(np.mean(np.array(p_train_losses)))

        sharpness = exp_p_error - train_loss
        sharpness_list.append(sharpness)
    
    avg_weight_norms_list.append(weight_norms_list)
    avg_sharpness_list.append(sharpness_list)
    avg_std_list.append(std_list)
    avg_mean_list.append(mean_list)
# Out:
# seed::: 12345
# 54000 6000 10000
#
# Test set: Average loss: 0.5475, Accuracy: 8087/10000 (81%)
#
#
# Test set: Average loss: 0.4967, Accuracy: 8214/10000 (82%)
#
#
# Test set: Average loss: 0.4726, Accuracy: 8270/10000 (83%)
#
#
# Test set: Average loss: 0.4581, Accuracy: 8319/10000 (83%)
#
#
# Test set: Average loss: 0.4509, Accuracy: 8332/10000 (83%)
#
#
# Test set: Average loss: 0.4456, Accuracy: 8354/10000 (84%)
#
#
# Test set: Average loss: 0.4407, Accuracy: 8354/10000 (84%)
#
#
# Test set: Average loss: 0.4399, Accuracy: 8370/10000 (84%)
#
#
# Test set: Average loss: 0.4367, Accuracy: 8373/10000 (84%)
#
#
# Test set: Average loss: 0.4358, Accuracy: 8371/10000 (84%)
#
#
# Test set: Average loss: 0.4361, Accuracy: 8381/10000 (84%)
#
#
# Test set: Average loss: 0.4358, Accuracy: 8379/10000 (84%)
#
#
# Test set: Average loss: 0.4342, Accuracy: 8383/10000 (84%)
#
#
# Test set: Average loss: 0.4342, Accuracy: 8384/10000 (84%)
#
# running for sigmas
#
# Test set: Average loss: 0.4267, Accuracy: 45585/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45596/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45594/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45582/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45591/54000 (84%)
#
#
# Test set: Average loss: 0.4267, Accuracy: 45604/54000 (84%)
#
#
# Test set: Average loss: 0.4269, Accuracy: 45596/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45589/54000 (84%)
#
#
# Test set: Average loss: 0.4267, Accuracy: 45588/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45594/54000 (84%)
#
#
# Test set: Average loss: 0.4267, Accuracy: 45575/54000 (84%)
#
#
# Test set: Average loss: 0.4267, Accuracy: 45597/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45581/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45589/54000 (84%)
#
#
# Test set: Average loss: 0.4266, Accuracy: 45604/54000 (84%)
#
#
# Test set: Average loss: 0.4267, Accuracy: 45598/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45592/54000 (84%)
#
#
# Test set: Average loss: 0.4266, Accuracy: 45586/54000 (84%)
#
#
# Test set: Average loss: 0.4268, Accuracy: 45592/54000 (84%)
#
#
# Test set: Average loss: 0.4267, Accuracy: 45595/54000 (84%)
#
#
# Test set: Average loss: 0.4286, Accuracy: 45569/54000 (84%)
#
#
# Test set: Average loss: 0.4282, Accuracy: 45552/54000 (84%)
#
#
# Test set: Average loss: 0.4283, Accuracy: 45596/54000 (84%)
#
#
# Test set: Average loss: 0.4286, Accuracy: 45556/54000 (84%)
#
#
# Test set: Average loss: 0.4281, Accuracy: 45569/54000 (84%)
#
#
# Test set: Average loss: 0.4282, Accuracy: 45564/54000 (84%)
#
#
# Test set: Average loss: 0.4287, Accuracy: 45551/54000 (84%)
#
#
# Test set: Average loss: 0.4290, Accuracy: 45555/54000 (84%)
#
#
# Test set: Average loss: 0.4288, Accuracy: 45538/54000 (84%)
#
#
# Test set: Average loss: 0.4291, Accuracy: 45552/54000 (84%)
#
#
# Test set: Average loss: 0.4287, Accuracy: 45550/54000 (84%)
#
#
# Test set: Average loss: 0.4281, Accuracy: 45547/54000 (84%)
#
#
# Test set: Average loss: 0.4282, Accuracy: 45574/54000 (84%)
#
#
# Test set: Average loss: 0.4278, Accuracy: 45565/54000 (84%)
#
#
# Test set: Average loss: 0.4284, Accuracy: 45575/54000 (84%)
#
#
# Test set: Average loss: 0.4283, Accuracy: 45563/54000 (84%)
#
#
# Test set: Average loss: 0.4284, Accuracy: 45574/54000 (84%)
#
#
# Test set: Average loss: 0.4279, Accuracy: 45568/54000 (84%)
#
#
# Test set: Average loss: 0.4285, Accuracy: 45574/54000 (84%)
#
#
# Test set: Average loss: 0.4285, Accuracy: 45558/54000 (84%)
#
#
# Test set: Average loss: 0.4318, Accuracy: 45521/54000 (84%)
#
#
# Test set: Average loss: 0.4326, Accuracy: 45486/54000 (84%)
#
#
# Test set: Average loss: 0.4325, Accuracy: 45489/54000 (84%)
#
#
# Test set: Average loss: 0.4364, Accuracy: 45426/54000 (84%)
#
#
# Test set: Average loss: 0.4318, Accuracy: 45494/54000 (84%)
#
#
# Test set: Average loss: 0.4360, Accuracy: 45410/54000 (84%)
#
#
# Test set: Average loss: 0.4342, Accuracy: 45434/54000 (84%)
#
#
# Test set: Average loss: 0.4335, Accuracy: 45485/54000 (84%)
#
#
# Test set: Average loss: 0.4361, Accuracy: 45406/54000 (84%)
#
#
# Test set: Average loss: 0.4350, Accuracy: 45429/54000 (84%)
#
#
# Test set: Average loss: 0.4336, Accuracy: 45488/54000 (84%)
#
#
# Test set: Average loss: 0.4338, Accuracy: 45486/54000 (84%)
#
#
# Test set: Average loss: 0.4342, Accuracy: 45465/54000 (84%)
#
#
# Test set: Average loss: 0.4367, Accuracy: 45395/54000 (84%)
#
#
# Test set: Average loss: 0.4334, Accuracy: 45480/54000 (84%)
#
#
# Test set: Average loss: 0.4363, Accuracy: 45390/54000 (84%)
#
#
# Test set: Average loss: 0.4325, Accuracy: 45490/54000 (84%)
#
#
# Test set: Average loss: 0.4347, Accuracy: 45478/54000 (84%)
#
#
# Test set: Average loss: 0.4366, Accuracy: 45444/54000 (84%)
#
#
# Test set: Average loss: 0.4336, Accuracy: 45496/54000 (84%)
#
#
# Test set: Average loss: 0.4477, Accuracy: 45306/54000 (84%)
#
#
# Test set: Average loss: 0.4483, Accuracy: 45264/54000 (84%)
#
#
# Test set: Average loss: 0.4510, Accuracy: 45184/54000 (84%)
#
#
# Test set: Average loss: 0.4385, Accuracy: 45387/54000 (84%)
#
#
# Test set: Average loss: 0.4482, Accuracy: 45194/54000 (84%)
#
#
# Test set: Average loss: 0.4423, Accuracy: 45385/54000 (84%)
#
#
# Test set: Average loss: 0.4418, Accuracy: 45324/54000 (84%)
#
#
# Test set: Average loss: 0.4480, Accuracy: 45310/54000 (84%)
#
#
# Test set: Average loss: 0.4400, Accuracy: 45379/54000 (84%)
#
#
# Test set: Average loss: 0.4411, Accuracy: 47328/54000 (88%)
#
#
# Test set: Average loss: 0.4463, Accuracy: 45266/54000 (84%)
#
#
# Test set: Average loss: 0.4500, Accuracy: 45240/54000 (84%)
#
#
# Test set: Average loss: 0.4386, Accuracy: 45439/54000 (84%)
#
#
# Test set: Average loss: 0.4422, Accuracy: 45321/54000 (84%)
#
#
# Test set: Average loss: 0.4473, Accuracy: 45262/54000 (84%)
#
#
# Test set: Average loss: 0.4417, Accuracy: 45378/54000 (84%)
#
#
# Test set: Average loss: 0.4514, Accuracy: 45194/54000 (84%)
#
#
# Test set: Average loss: 0.4459, Accuracy: 45317/54000 (84%)
#
#
# Test set: Average loss: 0.4528, Accuracy: 45025/54000 (83%)
#
#
# Test set: Average loss: 0.4439, Accuracy: 45308/54000 (84%)
#
#
# Test set: Average loss: 0.9684, Accuracy: 36131/54000 (67%)
#
#
# Test set: Average loss: 0.9470, Accuracy: 35820/54000 (66%)
#
#
# Test set: Average loss: 0.7844, Accuracy: 38979/54000 (72%)
#
#
# Test set: Average loss: 0.8902, Accuracy: 37786/54000 (70%)
#
#
# Test set: Average loss: 0.6967, Accuracy: 40632/54000 (75%)
#
#
# Test set: Average loss: 0.9605, Accuracy: 35124/54000 (65%)
#
#
# Test set: Average loss: 0.6288, Accuracy: 45329/54000 (84%)
#
#
# Test set: Average loss: 0.9655, Accuracy: 35653/54000 (66%)
#
#
# Test set: Average loss: 0.9765, Accuracy: 35189/54000 (65%)
#
#
# Test set: Average loss: 0.8410, Accuracy: 38241/54000 (71%)
#
#
# Test set: Average loss: 0.7911, Accuracy: 41262/54000 (76%)
#
#
# Test set: Average loss: 0.7984, Accuracy: 38583/54000 (71%)
#
#
# Test set: Average loss: 0.9010, Accuracy: 38297/54000 (71%)
#
#
# Test set: Average loss: 0.8857, Accuracy: 37103/54000 (69%)
#
#
# Test set: Average loss: 0.7202, Accuracy: 42665/54000 (79%)
#
#
# Test set: Average loss: 0.7088, Accuracy: 40361/54000 (75%)
#
#
# Test set: Average loss: 0.8008, Accuracy: 38822/54000 (72%)
#
#
# Test set: Average loss: 1.0218, Accuracy: 36649/54000 (68%)
#
#
# Test set: Average loss: 0.8273, Accuracy: 37791/54000 (70%)
#
#
# Test set: Average loss: 0.8838, Accuracy: 37552/54000 (70%)
#
#
# Test set: Average loss: 5.9994, Accuracy: 10227/54000 (19%)
#
#
# Test set: Average loss: 4.3149, Accuracy: 12534/54000 (23%)
#
#
# Test set: Average loss: 3.9633, Accuracy: 13855/54000 (26%)
#
#
# Test set: Average loss: 3.3352, Accuracy: 17740/54000 (33%)
#
#
# Test set: Average loss: 5.9971, Accuracy: 11221/54000 (21%)
#
#
# Test set: Average loss: 5.1038, Accuracy: 12330/54000 (23%)
#
#
# Test set: Average loss: 5.2909, Accuracy: 13793/54000 (26%)
#
#
# Test set: Average loss: 4.4673, Accuracy: 12687/54000 (23%)
#
#
# Test set: Average loss: 4.2842, Accuracy: 13193/54000 (24%)
#
#
# Test set: Average loss: 5.2276, Accuracy: 18661/54000 (35%)
#
#
# Test set: Average loss: 3.7692, Accuracy: 13050/54000 (24%)
#
#
# Test set: Average loss: 5.3462, Accuracy: 9301/54000 (17%)
#
#
# Test set: Average loss: 3.4945, Accuracy: 14509/54000 (27%)
#
#
# Test set: Average loss: 9.0177, Accuracy: 6494/54000 (12%)
#
#
# Test set: Average loss: 4.4687, Accuracy: 17667/54000 (33%)
#
#
# Test set: Average loss: 5.1827, Accuracy: 7525/54000 (14%)
#
#
# Test set: Average loss: 3.4901, Accuracy: 15557/54000 (29%)
#
#
# Test set: Average loss: 4.0138, Accuracy: 13724/54000 (25%)
#
#
# Test set: Average loss: 6.1167, Accuracy: 14650/54000 (27%)
#
#
# Test set: Average loss: 7.3199, Accuracy: 10520/54000 (19%)
#
#
# Test set: Average loss: 25.7635, Accuracy: 4910/54000 (9%)
#
#
# Test set: Average loss: 14.4636, Accuracy: 9366/54000 (17%)
#
#
# Test set: Average loss: 28.8301, Accuracy: 6154/54000 (11%)
#
#
# Test set: Average loss: 17.2395, Accuracy: 4544/54000 (8%)
#
#
# Test set: Average loss: 14.8693, Accuracy: 8544/54000 (16%)
#
#
# Test set: Average loss: 20.0287, Accuracy: 7899/54000 (15%)
#
#
# Test set: Average loss: 16.1336, Accuracy: 7774/54000 (14%)
#
#
# Test set: Average loss: 10.7936, Accuracy: 8012/54000 (15%)
#
#
# Test set: Average loss: 11.6609, Accuracy: 8452/54000 (16%)
#
#
# Test set: Average loss: 28.1101, Accuracy: 8481/54000 (16%)
#
#
# Test set: Average loss: 14.2133, Accuracy: 9304/54000 (17%)
#
#
# Test set: Average loss: 15.5808, Accuracy: 6034/54000 (11%)
#
#
# Test set: Average loss: 7.7900, Accuracy: 9691/54000 (18%)
#
#
# Test set: Average loss: 17.4866, Accuracy: 7598/54000 (14%)
#
#
# Test set: Average loss: 18.0523, Accuracy: 8662/54000 (16%)
#
#
# Test set: Average loss: 12.9611, Accuracy: 7636/54000 (14%)
#
#
# Test set: Average loss: 15.2828, Accuracy: 10031/54000 (19%)
#
#
# Test set: Average loss: 14.1680, Accuracy: 7235/54000 (13%)
#
#
# Test set: Average loss: 17.7684, Accuracy: 9017/54000 (17%)
#
#
# Test set: Average loss: 19.4129, Accuracy: 8404/54000 (16%)
#
# seed::: 1234
# 54000 6000 10000
#
# Test set: Average loss: 0.2915, Accuracy: 9171/10000 (92%)
#
#
# Test set: Average loss: 0.2417, Accuracy: 9315/10000 (93%)
#
#
# Test set: Average loss: 0.2153, Accuracy: 9376/10000 (94%)
#
#
# Test set: Average loss: 0.2028, Accuracy: 9410/10000 (94%)
#
#
# Test set: Average loss: 0.1949, Accuracy: 9436/10000 (94%)
#
#
# Test set: Average loss: 0.1903, Accuracy: 9444/10000 (94%)
#
#
# Test set: Average loss: 0.1855, Accuracy: 9462/10000 (95%)
#
#
# Test set: Average loss: 0.1833, Accuracy: 9460/10000 (95%)
#
#
# Test set: Average loss: 0.1817, Accuracy: 9461/10000 (95%)
#
#
# Test set: Average loss: 0.1802, Accuracy: 9471/10000 (95%)
#
#
# Test set: Average loss: 0.1782, Accuracy: 9475/10000 (95%)
#
#
# Test set: Average loss: 0.1779, Accuracy: 9474/10000 (95%)
#
#
# Test set: Average loss: 0.1777, Accuracy: 9476/10000 (95%)
#
#
# Test set: Average loss: 0.1781, Accuracy: 9478/10000 (95%)
#
# running for sigmas
#
# Test set: Average loss: 0.1734, Accuracy: 51370/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51366/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51346/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51361/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51345/54000 (95%)
#
#
# Test set: Average loss: 0.1736, Accuracy: 51373/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51346/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51365/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51356/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51364/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51356/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51356/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51352/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51365/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51365/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51367/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51377/54000 (95%)
#
#
# Test set: Average loss: 0.1734, Accuracy: 51358/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51366/54000 (95%)
#
#
# Test set: Average loss: 0.1735, Accuracy: 51358/54000 (95%)
#
#
# Test set: Average loss: 0.1756, Accuracy: 51297/54000 (95%)
#
#
# Test set: Average loss: 0.1756, Accuracy: 51319/54000 (95%)
#
#
# Test set: Average loss: 0.1751, Accuracy: 51353/54000 (95%)
#
#
# Test set: Average loss: 0.1752, Accuracy: 51294/54000 (95%)
#
#
# Test set: Average loss: 0.1757, Accuracy: 51331/54000 (95%)
#
#
# Test set: Average loss: 0.1760, Accuracy: 51336/54000 (95%)
#
#
# Test set: Average loss: 0.1750, Accuracy: 51352/54000 (95%)
#
#
# Test set: Average loss: 0.1752, Accuracy: 51328/54000 (95%)
#
#
# Test set: Average loss: 0.1749, Accuracy: 51331/54000 (95%)
#
#
# Test set: Average loss: 0.1750, Accuracy: 51327/54000 (95%)
#
#
# Test set: Average loss: 0.1754, Accuracy: 51318/54000 (95%)
#
#
# Test set: Average loss: 0.1748, Accuracy: 51328/54000 (95%)
#
#
# Test set: Average loss: 0.1755, Accuracy: 51316/54000 (95%)
#
#
# Test set: Average loss: 0.1758, Accuracy: 51338/54000 (95%)
#
#
# Test set: Average loss: 0.1761, Accuracy: 51326/54000 (95%)
#
#
# Test set: Average loss: 0.1750, Accuracy: 51321/54000 (95%)
#
#
# Test set: Average loss: 0.1756, Accuracy: 51341/54000 (95%)
#
#
# Test set: Average loss: 0.1751, Accuracy: 51327/54000 (95%)
#
#
# Test set: Average loss: 0.1749, Accuracy: 51334/54000 (95%)
#
#
# Test set: Average loss: 0.1749, Accuracy: 51340/54000 (95%)
#
#
# Test set: Average loss: 0.1797, Accuracy: 51252/54000 (95%)
#
#
# Test set: Average loss: 0.1806, Accuracy: 51255/54000 (95%)
#
#
# Test set: Average loss: 0.1793, Accuracy: 51252/54000 (95%)
#
#
# Test set: Average loss: 0.1804, Accuracy: 51245/54000 (95%)
#
#
# Test set: Average loss: 0.1794, Accuracy: 51304/54000 (95%)
#
#
# Test set: Average loss: 0.1785, Accuracy: 51264/54000 (95%)
#
#
# Test set: Average loss: 0.1829, Accuracy: 51220/54000 (95%)
#
#
# Test set: Average loss: 0.1808, Accuracy: 51293/54000 (95%)
#
#
# Test set: Average loss: 0.1827, Accuracy: 51220/54000 (95%)
#
#
# Test set: Average loss: 0.1818, Accuracy: 51228/54000 (95%)
#
#
# Test set: Average loss: 0.1858, Accuracy: 51188/54000 (95%)
#
#
# Test set: Average loss: 0.1810, Accuracy: 51251/54000 (95%)
#
#
# Test set: Average loss: 0.1807, Accuracy: 51252/54000 (95%)
#
#
# Test set: Average loss: 0.1812, Accuracy: 51259/54000 (95%)
#
#
# Test set: Average loss: 0.1808, Accuracy: 51281/54000 (95%)
#
#
# Test set: Average loss: 0.1808, Accuracy: 51255/54000 (95%)
#
#
# Test set: Average loss: 0.1831, Accuracy: 51218/54000 (95%)
#
#
# Test set: Average loss: 0.1818, Accuracy: 51232/54000 (95%)
#
#
# Test set: Average loss: 0.1809, Accuracy: 51245/54000 (95%)
#
#
# Test set: Average loss: 0.1817, Accuracy: 51257/54000 (95%)
#
#
# Test set: Average loss: 0.1889, Accuracy: 51192/54000 (95%)
#
#
# Test set: Average loss: 0.1893, Accuracy: 51167/54000 (95%)
#
#
# Test set: Average loss: 0.1960, Accuracy: 50985/54000 (94%)
#
#
# Test set: Average loss: 0.1952, Accuracy: 51045/54000 (95%)
#
#
# Test set: Average loss: 0.1929, Accuracy: 51174/54000 (95%)
#
#
# Test set: Average loss: 0.1922, Accuracy: 51097/54000 (95%)
#
#
# Test set: Average loss: 0.1893, Accuracy: 51101/54000 (95%)
#
#
# Test set: Average loss: 0.1956, Accuracy: 51022/54000 (94%)
#
#
# Test set: Average loss: 0.1928, Accuracy: 51189/54000 (95%)
#
#
# Test set: Average loss: 0.1994, Accuracy: 50926/54000 (94%)
#
#
# Test set: Average loss: 0.1918, Accuracy: 51126/54000 (95%)
#
#
# Test set: Average loss: 0.1909, Accuracy: 51111/54000 (95%)
#
#
# Test set: Average loss: 0.1991, Accuracy: 50981/54000 (94%)
#
#
# Test set: Average loss: 0.1929, Accuracy: 51053/54000 (95%)
#
#
# Test set: Average loss: 0.1932, Accuracy: 51052/54000 (95%)
#
#
# Test set: Average loss: 0.1963, Accuracy: 51015/54000 (94%)
#
#
# Test set: Average loss: 0.2011, Accuracy: 50877/54000 (94%)
#
#
# Test set: Average loss: 0.1888, Accuracy: 51173/54000 (95%)
#
#
# Test set: Average loss: 0.1930, Accuracy: 51041/54000 (95%)
#
#
# Test set: Average loss: 0.1889, Accuracy: 51187/54000 (95%)
#
#
# Test set: Average loss: 0.5215, Accuracy: 44733/54000 (83%)
#
#
# Test set: Average loss: 0.7035, Accuracy: 43755/54000 (81%)
#
#
# Test set: Average loss: 0.6699, Accuracy: 41749/54000 (77%)
#
#
# Test set: Average loss: 0.4468, Accuracy: 46011/54000 (85%)
#
#
# Test set: Average loss: 0.7396, Accuracy: 39944/54000 (74%)
#
#
# Test set: Average loss: 1.0580, Accuracy: 30852/54000 (57%)
#
#
# Test set: Average loss: 0.9854, Accuracy: 34881/54000 (65%)
#
#
# Test set: Average loss: 0.8555, Accuracy: 37595/54000 (70%)
#
#
# Test set: Average loss: 0.5319, Accuracy: 44952/54000 (83%)
#
#
# Test set: Average loss: 0.4565, Accuracy: 46332/54000 (86%)
#
#
# Test set: Average loss: 0.4436, Accuracy: 46604/54000 (86%)
#
#
# Test set: Average loss: 0.5999, Accuracy: 42705/54000 (79%)
#
#
# Test set: Average loss: 0.9118, Accuracy: 37868/54000 (70%)
#
#
# Test set: Average loss: 0.8901, Accuracy: 37337/54000 (69%)
#
#
# Test set: Average loss: 0.4623, Accuracy: 45325/54000 (84%)
#
#
# Test set: Average loss: 0.7781, Accuracy: 39301/54000 (73%)
#
#
# Test set: Average loss: 0.5548, Accuracy: 43668/54000 (81%)
#
#
# Test set: Average loss: 0.5580, Accuracy: 44248/54000 (82%)
#
#
# Test set: Average loss: 0.6826, Accuracy: 41224/54000 (76%)
#
#
# Test set: Average loss: 0.6519, Accuracy: 42162/54000 (78%)
#
#
# Test set: Average loss: 5.4509, Accuracy: 16183/54000 (30%)
#
#
# Test set: Average loss: 4.6474, Accuracy: 14614/54000 (27%)
#
#
# Test set: Average loss: 4.4775, Accuracy: 14457/54000 (27%)
#
#
# Test set: Average loss: 7.8319, Accuracy: 10118/54000 (19%)
#
#
# Test set: Average loss: 3.4917, Accuracy: 14838/54000 (27%)
#
#
# Test set: Average loss: 4.0422, Accuracy: 14608/54000 (27%)
#
#
# Test set: Average loss: 6.9240, Accuracy: 9309/54000 (17%)
#
#
# Test set: Average loss: 4.8569, Accuracy: 13908/54000 (26%)
#
#
# Test set: Average loss: 7.4188, Accuracy: 10273/54000 (19%)
#
#
# Test set: Average loss: 5.7595, Accuracy: 13942/54000 (26%)
#
#
# Test set: Average loss: 5.5359, Accuracy: 12429/54000 (23%)
#
#
# Test set: Average loss: 5.0773, Accuracy: 12491/54000 (23%)
#
#
# Test set: Average loss: 9.1359, Accuracy: 9945/54000 (18%)
#
#
# Test set: Average loss: 5.9829, Accuracy: 14213/54000 (26%)
#
#
# Test set: Average loss: 5.0934, Accuracy: 14180/54000 (26%)
#
#
# Test set: Average loss: 4.7580, Accuracy: 13902/54000 (26%)
#
#
# Test set: Average loss: 7.5830, Accuracy: 10295/54000 (19%)
#
#
# Test set: Average loss: 5.3407, Accuracy: 12038/54000 (22%)
#
#
# Test set: Average loss: 4.1718, Accuracy: 17867/54000 (33%)
#
#
# Test set: Average loss: 5.3594, Accuracy: 11631/54000 (22%)
#
#
# Test set: Average loss: 15.9250, Accuracy: 8167/54000 (15%)
#
#
# Test set: Average loss: 14.3580, Accuracy: 11384/54000 (21%)
#
#
# Test set: Average loss: 20.7276, Accuracy: 6772/54000 (13%)
#
#
# Test set: Average loss: 14.9469, Accuracy: 6980/54000 (13%)
#
#
# Test set: Average loss: 31.1312, Accuracy: 4889/54000 (9%)
#
#
# Test set: Average loss: 8.0868, Accuracy: 9432/54000 (17%)
#
#
# Test set: Average loss: 18.9414, Accuracy: 6983/54000 (13%)
#
#
# Test set: Average loss: 13.1039, Accuracy: 12326/54000 (23%)
#
#
# Test set: Average loss: 15.3885, Accuracy: 7221/54000 (13%)
#
#
# Test set: Average loss: 16.7299, Accuracy: 7687/54000 (14%)
#
#
# Test set: Average loss: 19.9865, Accuracy: 8936/54000 (17%)
#
#
# Test set: Average loss: 17.4682, Accuracy: 6475/54000 (12%)
#
#
# Test set: Average loss: 16.2293, Accuracy: 5073/54000 (9%)
#
#
# Test set: Average loss: 27.0062, Accuracy: 5074/54000 (9%)
#
#
# Test set: Average loss: 18.3582, Accuracy: 8583/54000 (16%)
#
#
# Test set: Average loss: 19.1701, Accuracy: 9620/54000 (18%)
#
#
# Test set: Average loss: 32.7139, Accuracy: 6915/54000 (13%)
#
#
# Test set: Average loss: 14.5680, Accuracy: 5732/54000 (11%)
#
#
# Test set: Average loss: 25.8076, Accuracy: 5581/54000 (10%)
#
#
# Test set: Average loss: 13.1322, Accuracy: 9304/54000 (17%)
#
# seed::: 123
# 54000 6000 10000
#
# Test set: Average loss: 0.2873, Accuracy: 9198/10000 (92%)
#
#
# Test set: Average loss: 0.2410, Accuracy: 9301/10000 (93%)
#
#
# Test set: Average loss: 0.2178, Accuracy: 9363/10000 (94%)
#
#
# Test set: Average loss: 0.2033, Accuracy: 9418/10000 (94%)
#
#
# Test set: Average loss: 0.1970, Accuracy: 9440/10000 (94%)
#
#
# Test set: Average loss: 0.1891, Accuracy: 9454/10000 (95%)
#
#
# Test set: Average loss: 0.1865, Accuracy: 9463/10000 (95%)
#
#
# Test set: Average loss: 0.1832, Accuracy: 9470/10000 (95%)
#
#
# Test set: Average loss: 0.1817, Accuracy: 9470/10000 (95%)
#
#
# Test set: Average loss: 0.1808, Accuracy: 9475/10000 (95%)
#
#
# Test set: Average loss: 0.1793, Accuracy: 9479/10000 (95%)
#
#
# Test set: Average loss: 0.1797, Accuracy: 9480/10000 (95%)
#
#
# Test set: Average loss: 0.1790, Accuracy: 9483/10000 (95%)
#
#
# Test set: Average loss: 0.1782, Accuracy: 9484/10000 (95%)
#
# running for sigmas
#
# Test set: Average loss: 0.1767, Accuracy: 51301/54000 (95%)
#
#
# Test set: Average loss: 0.1768, Accuracy: 51317/54000 (95%)
#
#
# Test set: Average loss: 0.1769, Accuracy: 51312/54000 (95%)
#
#
# Test set: Average loss: 0.1769, Accuracy: 51307/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51306/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51319/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51316/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51316/54000 (95%)
#
#
# Test set: Average loss: 0.1768, Accuracy: 51300/54000 (95%)
#
#
# Test set: Average loss: 0.1768, Accuracy: 51308/54000 (95%)
#
#
# Test set: Average loss: 0.1768, Accuracy: 51308/54000 (95%)
#
#
# Test set: Average loss: 0.1768, Accuracy: 51296/54000 (95%)
#
#
# Test set: Average loss: 0.1768, Accuracy: 51304/54000 (95%)
#
#
# Test set: Average loss: 0.1769, Accuracy: 51297/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51305/54000 (95%)
#
#
# Test set: Average loss: 0.1768, Accuracy: 51292/54000 (95%)
#
#
# Test set: Average loss: 0.1769, Accuracy: 51308/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51299/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51301/54000 (95%)
#
#
# Test set: Average loss: 0.1767, Accuracy: 51314/54000 (95%)
#
#
# Test set: Average loss: 0.1786, Accuracy: 51268/54000 (95%)
#
#
# Test set: Average loss: 0.1787, Accuracy: 51267/54000 (95%)
#
#
# Test set: Average loss: 0.1788, Accuracy: 51272/54000 (95%)
#
#
# Test set: Average loss: 0.1784, Accuracy: 51281/54000 (95%)
#
#
# Test set: Average loss: 0.1791, Accuracy: 51273/54000 (95%)
#
#
# Test set: Average loss: 0.1784, Accuracy: 51272/54000 (95%)
#
#
# Test set: Average loss: 0.1793, Accuracy: 51252/54000 (95%)
#
#
# Test set: Average loss: 0.1786, Accuracy: 51269/54000 (95%)
#
#
# Test set: Average loss: 0.1788, Accuracy: 51272/54000 (95%)
#
#
# Test set: Average loss: 0.1786, Accuracy: 51293/54000 (95%)
#
#
# Test set: Average loss: 0.1790, Accuracy: 51303/54000 (95%)
#
#
# Test set: Average loss: 0.1788, Accuracy: 51283/54000 (95%)
#
#
# Test set: Average loss: 0.1784, Accuracy: 51288/54000 (95%)
#
#
# Test set: Average loss: 0.1798, Accuracy: 51247/54000 (95%)
#
#
# Test set: Average loss: 0.1782, Accuracy: 51285/54000 (95%)
#
#
# Test set: Average loss: 0.1784, Accuracy: 51289/54000 (95%)
#
#
# Test set: Average loss: 0.1781, Accuracy: 51287/54000 (95%)
#
#
# Test set: Average loss: 0.1786, Accuracy: 51248/54000 (95%)
#
#
# Test set: Average loss: 0.1790, Accuracy: 51237/54000 (95%)
#
#
# Test set: Average loss: 0.1788, Accuracy: 51280/54000 (95%)
#
#
# Test set: Average loss: 0.1871, Accuracy: 51094/54000 (95%)
#
#
# Test set: Average loss: 0.1846, Accuracy: 51151/54000 (95%)
#
#
# Test set: Average loss: 0.1848, Accuracy: 51195/54000 (95%)
#
#
# Test set: Average loss: 0.1848, Accuracy: 51211/54000 (95%)
#
#
# Test set: Average loss: 0.1902, Accuracy: 51060/54000 (95%)
#
#
# Test set: Average loss: 0.1837, Accuracy: 51219/54000 (95%)
#
#
# Test set: Average loss: 0.1859, Accuracy: 51158/54000 (95%)
#
#
# Test set: Average loss: 0.1878, Accuracy: 51217/54000 (95%)
#
#
# Test set: Average loss: 0.1858, Accuracy: 51182/54000 (95%)
#
#
# Test set: Average loss: 0.1838, Accuracy: 51193/54000 (95%)
#
#
# Test set: Average loss: 0.1855, Accuracy: 51173/54000 (95%)
#
#
# Test set: Average loss: 0.1847, Accuracy: 51216/54000 (95%)
#
#
# Test set: Average loss: 0.1869, Accuracy: 51181/54000 (95%)
#
#
# Test set: Average loss: 0.1835, Accuracy: 51219/54000 (95%)
#
#
# Test set: Average loss: 0.1853, Accuracy: 51154/54000 (95%)
#
#
# Test set: Average loss: 0.1839, Accuracy: 51237/54000 (95%)
#
#
# Test set: Average loss: 0.1851, Accuracy: 51143/54000 (95%)
#
#
# Test set: Average loss: 0.1846, Accuracy: 51160/54000 (95%)
#
#
# Test set: Average loss: 0.1844, Accuracy: 51195/54000 (95%)
#
#
# Test set: Average loss: 0.1842, Accuracy: 51233/54000 (95%)
#
#
# Test set: Average loss: 0.1976, Accuracy: 50947/54000 (94%)
#
#
# Test set: Average loss: 0.1963, Accuracy: 51020/54000 (94%)
#
#
# Test set: Average loss: 0.1975, Accuracy: 50940/54000 (94%)
#
#
# Test set: Average loss: 0.1909, Accuracy: 51104/54000 (95%)
#
#
# Test set: Average loss: 0.2017, Accuracy: 50917/54000 (94%)
#
#
# Test set: Average loss: 0.1899, Accuracy: 51124/54000 (95%)
#
#
# Test set: Average loss: 0.1934, Accuracy: 51058/54000 (95%)
#
#
# Test set: Average loss: 0.1929, Accuracy: 51061/54000 (95%)
#
#
# Test set: Average loss: 0.1971, Accuracy: 51053/54000 (95%)
#
#
# Test set: Average loss: 0.1981, Accuracy: 51012/54000 (94%)
#
#
# Test set: Average loss: 0.2055, Accuracy: 50809/54000 (94%)
#
#
# Test set: Average loss: 0.1939, Accuracy: 51009/54000 (94%)
#
#
# Test set: Average loss: 0.1974, Accuracy: 51033/54000 (95%)
#
#
# Test set: Average loss: 0.2035, Accuracy: 50787/54000 (94%)
#
#
# Test set: Average loss: 0.1955, Accuracy: 51035/54000 (95%)
#
#
# Test set: Average loss: 0.1979, Accuracy: 50940/54000 (94%)
#
#
# Test set: Average loss: 0.1958, Accuracy: 50989/54000 (94%)
#
#
# Test set: Average loss: 0.1964, Accuracy: 51038/54000 (95%)
#
#
# Test set: Average loss: 0.2003, Accuracy: 51006/54000 (94%)
#
#
# Test set: Average loss: 0.1974, Accuracy: 51051/54000 (95%)
#
#
# Test set: Average loss: 0.5485, Accuracy: 44437/54000 (82%)
#
#
# Test set: Average loss: 0.8343, Accuracy: 38235/54000 (71%)
#
#
# Test set: Average loss: 0.7017, Accuracy: 40656/54000 (75%)
#
#
# Test set: Average loss: 0.5150, Accuracy: 45227/54000 (84%)
#
#
# Test set: Average loss: 1.0675, Accuracy: 37676/54000 (70%)
#
#
# Test set: Average loss: 0.6927, Accuracy: 41624/54000 (77%)
#
#
# Test set: Average loss: 0.5985, Accuracy: 42997/54000 (80%)
#
#
# Test set: Average loss: 0.3920, Accuracy: 48081/54000 (89%)
#
#
# Test set: Average loss: 0.8122, Accuracy: 41823/54000 (77%)
#
#
# Test set: Average loss: 0.7031, Accuracy: 41212/54000 (76%)
#
#
# Test set: Average loss: 0.6805, Accuracy: 41674/54000 (77%)
#
#
# Test set: Average loss: 0.7738, Accuracy: 40051/54000 (74%)
#
#
# Test set: Average loss: 0.8712, Accuracy: 36537/54000 (68%)
#
#
# Test set: Average loss: 0.8275, Accuracy: 37918/54000 (70%)
#
#
# Test set: Average loss: 1.1813, Accuracy: 33122/54000 (61%)
#
#
# Test set: Average loss: 0.7995, Accuracy: 39431/54000 (73%)
#
#
# Test set: Average loss: 0.6930, Accuracy: 41456/54000 (77%)
#
#
# Test set: Average loss: 0.6055, Accuracy: 43078/54000 (80%)
#
#
# Test set: Average loss: 0.9520, Accuracy: 36026/54000 (67%)
#
#
# Test set: Average loss: 1.0056, Accuracy: 35234/54000 (65%)
#
#
# Test set: Average loss: 5.2357, Accuracy: 15863/54000 (29%)
#
#
# Test set: Average loss: 6.1894, Accuracy: 12799/54000 (24%)
#
#
# Test set: Average loss: 7.0013, Accuracy: 8826/54000 (16%)
#
#
# Test set: Average loss: 5.3325, Accuracy: 12847/54000 (24%)
#
#
# Test set: Average loss: 4.3996, Accuracy: 13157/54000 (24%)
#
#
# Test set: Average loss: 6.0846, Accuracy: 12970/54000 (24%)
#
#
# Test set: Average loss: 11.0423, Accuracy: 5985/54000 (11%)
#
#
# Test set: Average loss: 4.9065, Accuracy: 14408/54000 (27%)
#
#
# Test set: Average loss: 3.2141, Accuracy: 18998/54000 (35%)
#
#
# Test set: Average loss: 6.7747, Accuracy: 13682/54000 (25%)
#
#
# Test set: Average loss: 9.4121, Accuracy: 10441/54000 (19%)
#
#
# Test set: Average loss: 4.0907, Accuracy: 15489/54000 (29%)
#
#
# Test set: Average loss: 16.3203, Accuracy: 5021/54000 (9%)
#
#
# Test set: Average loss: 4.3553, Accuracy: 17750/54000 (33%)
#
#
# Test set: Average loss: 5.1193, Accuracy: 13502/54000 (25%)
#
#
# Test set: Average loss: 5.7444, Accuracy: 15639/54000 (29%)
#
#
# Test set: Average loss: 8.2189, Accuracy: 9784/54000 (18%)
#
#
# Test set: Average loss: 9.0910, Accuracy: 8273/54000 (15%)
#
#
# Test set: Average loss: 5.8920, Accuracy: 12176/54000 (23%)
#
#
# Test set: Average loss: 6.5112, Accuracy: 14209/54000 (26%)
#
#
# Test set: Average loss: 14.5247, Accuracy: 8200/54000 (15%)
#
#
# Test set: Average loss: 11.2047, Accuracy: 7693/54000 (14%)
#
#
# Test set: Average loss: 15.0523, Accuracy: 8836/54000 (16%)
#
#
# Test set: Average loss: 14.8773, Accuracy: 7328/54000 (14%)
#
#
# Test set: Average loss: 22.3757, Accuracy: 6241/54000 (12%)
#
#
# Test set: Average loss: 19.3991, Accuracy: 5932/54000 (11%)
#
#
# Test set: Average loss: 12.7096, Accuracy: 7532/54000 (14%)
#
#
# Test set: Average loss: 21.5952, Accuracy: 8072/54000 (15%)
#
#
# Test set: Average loss: 15.4913, Accuracy: 8753/54000 (16%)
#
#
# Test set: Average loss: 25.6874, Accuracy: 11234/54000 (21%)
#
#
# Test set: Average loss: 18.1244, Accuracy: 7183/54000 (13%)
#
#
# Test set: Average loss: 18.1052, Accuracy: 8293/54000 (15%)
#
#
# Test set: Average loss: 18.5305, Accuracy: 9040/54000 (17%)
#
#
# Test set: Average loss: 17.1129, Accuracy: 7851/54000 (15%)
#
#
# Test set: Average loss: 11.8349, Accuracy: 9330/54000 (17%)
#
#
# Test set: Average loss: 13.5371, Accuracy: 9498/54000 (18%)
#
#
# Test set: Average loss: 7.9372, Accuracy: 6512/54000 (12%)
#
#
# Test set: Average loss: 21.0544, Accuracy: 9105/54000 (17%)
#
#
# Test set: Average loss: 18.2472, Accuracy: 7952/54000 (15%)
#
#
# Test set: Average loss: 16.2918, Accuracy: 5929/54000 (11%)

# %%
print (avg_train_losses)
print (avg_test_losses)
print (avg_difference_test_train)
print (avg_weight_norms_list)
print (avg_sharpness_list)
print (avg_std_list)
# Out:
# [[0.8790427055827814, 0.5237629481224935, 0.4841278363284059, 0.4633967369371116, 0.4507265914213883, 0.44295816052863946, 0.43750981613993645, 0.4338455323606588, 0.43142776725310567, 0.42974860749926896, 0.42858962449841026, 0.427712890562288, 0.42717585310128064, 0.42671115566662987], [0.65503695001605, 0.27296583230002514, 0.23303344608306603, 0.2115077439572009, 0.19850451025176105, 0.19020772728874785, 0.18463822545139427, 0.1809778663184123, 0.17835245389155868, 0.17655792472204326, 0.17535277170027602, 0.17449101539090348, 0.17388609369501684, 0.17348301930626706], [0.6493379227305052, 0.2744213773988152, 0.23542707328689041, 0.2145292399919005, 0.20193981441064468, 0.19352358467523803, 0.18802725910363605, 0.18429441517881026, 0.18165152911229226, 0.17995155957567183, 0.17867813169320612, 0.17784340848254648, 0.17723287685257846, 0.17685340824691465]]
# [[0.5474568421293975, 0.4967189818430858, 0.4726096834916218, 0.45811461747451954, 0.45092130419175336, 0.4456136813209315, 0.4406717382608705, 0.43993828991416156, 0.4366547102761117, 0.4358461831405664, 0.4361173875962093, 0.4357713223642604, 0.4342409766213909, 0.4341702247691003], [0.2915296452535186, 0.2417272984222242, 0.2153348029608939, 0.20280513670414116, 0.19489860881096238, 0.1902616711416442, 0.18554981987757288, 0.1832700157716016, 0.18169922410113037, 0.1801867175159181, 0.17824270709115228, 0.1779052094099628, 0.1776891533451475, 0.17807304631372925], [0.2873293253456711, 0.2410193362813087, 0.2177919172177649, 0.2032669814434021, 0.19696312307552166, 0.18911915118242525, 0.18650635768463658, 0.18316278554451693, 0.1816583386841853, 0.18079443052885638, 0.1792913055533816, 0.17966696268813626, 0.17900584808960082, 0.17819222115027677]]
# [array([-3.31585863e-01, -2.70439663e-02, -1.15181528e-02, -5.28211946e-03,
#         1.94712770e-04,  2.65552079e-03,  3.16192212e-03,  6.09275755e-03,
#         5.22694302e-03,  6.09757564e-03,  7.52776310e-03,  8.05843180e-03,
#         7.06512352e-03,  7.45906910e-03]), array([-3.63507305e-01, -3.12385339e-02, -1.76986431e-02, -8.70260725e-03,
#        -3.60590144e-03,  5.39438529e-05,  9.11594426e-04,  2.29214945e-03,
#         3.34677021e-03,  3.62879279e-03,  2.88993539e-03,  3.41419402e-03,
#         3.80305965e-03,  4.59002701e-03]), array([-3.62008597e-01, -3.34020411e-02, -1.76351561e-02, -1.12622585e-02,
#        -4.97669134e-03, -4.40443349e-03, -1.52090142e-03, -1.13162963e-03,
#         6.80957189e-06,  8.42870953e-04,  6.13173860e-04,  1.82355421e-03,
#         1.77297124e-03,  1.33881290e-03])]
# [[328.74957275390625, 109.58320617675781, 54.7916374206543, 36.527793884277344, 10.958538055419922, 5.479597568511963, 3.6534297466278076], [328.7117919921875, 109.57061767578125, 54.78533935546875, 36.523597717285156, 10.95727825164795, 5.478967666625977, 3.653010129928589], [328.6943664550781, 109.56480407714844, 54.78243637084961, 36.52165985107422, 10.956697463989258, 5.478677272796631, 3.6528165340423584]]
# [[4.1737079055359505e-05, 0.0017271270816571205, 0.007568168780497264, 0.018645347734268847, 0.423179427440768, 4.583439568036471, 16.603742792550914], [-2.6383833800824874e-05, 0.0018244649433658555, 0.007713759397443454, 0.019903686397457376, 0.5015975936911824, 5.47346555550905, 18.515486199820145], [-7.206842554866033e-05, 0.0018681148272360892, 0.008474084943471155, 0.020112231259909574, 0.5859146020979891, 6.569942615393954, 16.507800116066015]]
# [[8.168881094974858e-05, 0.0003225642963898012, 0.0015971514721695118, 0.00428848636476909, 0.10579147737107746, 1.3691340886347954, 5.281046250090988], [5.834207932569808e-05, 0.00038373437731692835, 0.0015531233633108972, 0.0035824081754930485, 0.18310483983718503, 1.4075977263239283, 6.048694989257325], [7.485337565215692e-05, 0.00038013424727434175, 0.0015976246105069477, 0.003761665705334926, 0.18815973026340116, 2.9030816678586233, 4.135742980997826]]

# %%
# Averaging over 3 random seeds
avg_train_losses = np.mean(np.array(avg_train_losses), 0)
avg_test_losses = np.mean(np.array(avg_test_losses), 0)
avg_difference_test_train = np.mean(np.array(avg_difference_test_train), 0)

avg_weight_norms_list = np.mean(np.array(avg_weight_norms_list), 0)
avg_sharpness_list = np.mean(np.array(avg_sharpness_list), 0)
avg_std_list = np.mean(np.array(avg_std_list), 0)
avg_mean_list = np.mean(np.array(avg_mean_list), 0)


# print ("avg_train_losses:::\n", avg_train_losses)
# print ("avg_test_losses:::\n", avg_test_losses)
print ("average difference list::\n", avg_difference_test_train)
print ("avg_weight_norms_list::\n", avg_weight_norms_list)
print ("avg_sharpness_list::\n", avg_sharpness_list)
print ("avg_std_list::\n", avg_std_list)
print ("avg_mean_list::\n", avg_mean_list)
# Out:
# average difference list::
#  [-0.35236726 -0.03056151 -0.01561732 -0.00841566 -0.00279596 -0.00056499
#   0.00085087  0.00241776  0.00286017  0.00352308  0.00367696  0.00443206
#   0.00421372  0.00446264]
# avg_weight_norms_list::
#  [328.71857707 109.57287598  54.78647105  36.52435048  10.95750459
#    5.47908084   3.65308547]
# avg_sharpness_list::
#  [-1.89050601e-05  1.80656895e-03  7.91867104e-03  1.95537551e-02
#   5.03563874e-01  5.54228258e+00  1.72090097e+01]
# avg_std_list::
#  [7.16280886e-05 3.62144307e-04 1.58263315e-03 3.87752008e-03
#  1.59018682e-01 1.89327116e+00 5.15516141e+00]
# avg_mean_list::
#  [ 0.25899696  0.26082243  0.26693453  0.27856962  0.76257974  5.80129844
#  17.46802556]

# %%
# Plotting training
show_losses(avg_train_losses, avg_test_losses)

# %%
# Plotting Sharpness and Norm term from equation 1 in the report
# Weights are taken on a log scale
plt.plot(np.log(avg_weight_norms_list), avg_sharpness_list, marker='o')
plt.grid(True, linestyle='-.')
plt.title("Weight Norm and Sharpness")
plt.xlabel("Weight Norm")
plt.ylabel("Sharpness")
plt.show()
